# %%
from reader import JPGReader
from face_finder import CascadeFinder
import matplotlib.pyplot as plt

# %%
girl_path = r"C:\Users\wanghuan\desktop\projects\face_rec\resources\images\girls.jpeg"

reader = JPGReader()
reader.set_path(girl_path)
reader.read()
face_finder = CascadeFinder()
plt.imshow(face_finder.draw(reader.read()))
