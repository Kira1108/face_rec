# %%
from reader import JPGReader
from face_finder import CascadeFinder, MTCNNFinder
import matplotlib.pyplot as plt

# %%
girl_path = r"C:\Users\wanghuan\desktop\projects\face_rec\resources\images\girls.jpeg"

reader = JPGReader()
reader.set_path(girl_path)
reader.read()
face_finder = CascadeFinder()
face_finder = MTCNNFinder()
plt.imshow(face_finder.draw(reader.read()))

# %%
import face_recognition

# %%
import face_recognition

# Load the jpg files into numpy arrays
biden_image = face_recognition.load_image_file(r"C:\Users\wanghuan\desktop\projects\face_rec\resources\images\biden.jpg")
obama_image = face_recognition.load_image_file(r"C:\Users\wanghuan\desktop\projects\face_rec\resources\images\obama.jpg")
unknown_image = face_recognition.load_image_file(r"C:\Users\wanghuan\desktop\projects\face_rec\resources\images\obama2.jpg")

# Get the face encodings for each face in each image file
# Since there could be more than one face in each image, it returns a list of encodings.
# But since I know each image only has one face, I only care about the first encoding in each image, so I grab index 0.
try:
    biden_face_encoding = face_recognition.face_encodings(biden_image)[0]
    obama_face_encoding = face_recognition.face_encodings(obama_image)[0]
    unknown_face_encoding = face_recognition.face_encodings(unknown_image)[0]
except IndexError:
    print("I wasn't able to locate any faces in at least one of the images. Check the image files. Aborting...")
    quit()

known_faces = [
    biden_face_encoding,
    obama_face_encoding
]

# results is an array of True/False telling if the unknown face matched anyone in the known_faces array
results = face_recognition.compare_faces(known_faces, unknown_face_encoding)

print("Is the unknown face a picture of Biden? {}".format(results[0]))
print("Is the unknown face a picture of Obama? {}".format(results[1]))
print("Is the unknown face a new person that we've never seen before? {}".format(not True in results))
# Out:
# Is the unknown face a picture of Biden? False
# Is the unknown face a picture of Obama? True
# Is the unknown face a new person that we've never seen before? False

# %%
folder_path = r"C:\Users\wanghuan\desktop\projects\face_rec\resources\images"

import glob

glob.glob(os.path.join(folder_path, '*.jpg'))
# Out:
# ['C:\\Users\\wanghuan\\desktop\\projects\\face_rec\\resources\\images\\biden.jpg',
#  'C:\\Users\\wanghuan\\desktop\\projects\\face_rec\\resources\\images\\obama.jpg',
#  'C:\\Users\\wanghuan\\desktop\\projects\\face_rec\\resources\\images\\obama2.jpg']

# %%
files = os.listdir(folder_path)
{file.split('.')[0]:os.path.join(folder_path, file) for file in files}
# Out:
# {'biden': 'C:\\Users\\wanghuan\\desktop\\projects\\face_rec\\resources\\images\\biden.jpg',
#  'girls': 'C:\\Users\\wanghuan\\desktop\\projects\\face_rec\\resources\\images\\girls.jpeg',
#  'obama': 'C:\\Users\\wanghuan\\desktop\\projects\\face_rec\\resources\\images\\obama.jpg',
#  'obama2': 'C:\\Users\\wanghuan\\desktop\\projects\\face_rec\\resources\\images\\obama2.jpg'}

# %%
list({1:[3],2:[6]}.values())
# Out:
# [[3], [6]]
